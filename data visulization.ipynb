# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df= pd.read_excel("flight.xlsx")
df.head()
# Out:
#                  AIRLINE                AIRLINE_DOT AIRLINE_CODE  DOT_CODE  \
# 0  United Air Lines Inc.  United Air Lines Inc.: UA           UA     19977
# 1   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL     19790
# 2  United Air Lines Inc.  United Air Lines Inc.: UA           UA     19977
# 3   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL     19790
# 4       Spirit Air Lines       Spirit Air Lines: NK           NK     20416
#
#    FL_NUMBER ORIGIN          ORIGIN_CITY DEST              DEST_CITY  \
# 0       1562    FLL  Fort Lauderdale, FL  EWR             Newark, NJ
# 1       1149    MSP      Minneapolis, MN  SEA            Seattle, WA
# 2        459    DEN           Denver, CO  MSP        Minneapolis, MN
# 3       2295    MSP      Minneapolis, MN  SFO      San Francisco, CA
# 4        407    MCO          Orlando, FL  DFW  Dallas/Fort Worth, TX
#
#    CRS_DEP_TIME  ...  DIVERTED  CRS_ELAPSED_TIME  ELAPSED_TIME  AIR_TIME  \
# ...

# %%
df.columns
# Out:
# Index(['airline', 'airline_dot', 'airline_code', 'dot_code', 'fl_number',
#        'origin', 'origin_city', 'dest', 'dest_city', 'crs_dep_time',
#        'dep_time', 'dep_delay', 'taxi_out', 'wheels_off', 'wheels_on',
#        'taxi_in', 'crs_arr_time', 'arr_time', 'arr_delay', 'cancelled',
#        'cancellation_code', 'diverted', 'crs_elapsed_time', 'elapsed_time',
#        'air_time', 'distance', 'delay_due_carrier', 'delay_due_weather',
#        'delay_due_nas', 'delay_due_security', 'delay_due_late_aircraft'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 921 entries, 0 to 920
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   AIRLINE                  921 non-null    object
#  1   AIRLINE_DOT              921 non-null    object
#  2   AIRLINE_CODE             921 non-null    object
#  3   DOT_CODE                 921 non-null    int64
#  4   FL_NUMBER                921 non-null    int64
#  5   ORIGIN                   921 non-null    object
#  6   ORIGIN_CITY              921 non-null    object
#  7   DEST                     921 non-null    object
#  8   DEST_CITY                921 non-null    object
#  9   CRS_DEP_TIME             921 non-null    int64
#  10  DEP_TIME                 898 non-null    float64
#  11  DEP_DELAY                898 non-null    float64
#  12  TAXI_OUT                 898 non-null    float64
#  13  WHEELS_OFF               898 non-null    float64
# ...

# %%
# make column to low column 
df.columns = [str(name).lower() for name in df.columns.tolist()]
df.head()
# Out:
#                  airline                airline_dot airline_code  dot_code  \
# 0  United Air Lines Inc.  United Air Lines Inc.: UA           UA     19977
# 1   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL     19790
# 2  United Air Lines Inc.  United Air Lines Inc.: UA           UA     19977
# 3   Delta Air Lines Inc.   Delta Air Lines Inc.: DL           DL     19790
# 4       Spirit Air Lines       Spirit Air Lines: NK           NK     20416
#
#    fl_number origin          origin_city dest              dest_city  \
# 0       1562    FLL  Fort Lauderdale, FL  EWR             Newark, NJ
# 1       1149    MSP      Minneapolis, MN  SEA            Seattle, WA
# 2        459    DEN           Denver, CO  MSP        Minneapolis, MN
# 3       2295    MSP      Minneapolis, MN  SFO      San Francisco, CA
# 4        407    MCO          Orlando, FL  DFW  Dallas/Fort Worth, TX
#
#    crs_dep_time  ...  diverted  crs_elapsed_time  elapsed_time  air_time  \
# ...

# %%
airline_counts = df['airline'].value_counts()

# Generate colors
colors = plt.cm.tab10.colors 

# Plot the data
plt.barh(airline_counts.index, airline_counts.values, color=colors[:len(airline_counts)])
plt.xlabel('Number of counts')
plt.ylabel('Airline')
plt.title('Count of Airlines')
plt.show()

# %%
top_airline=df['airline'].value_counts()
top_airline = top_airline.nlargest(10)
print(top_airline)
# Out:
# airline
# Southwest Airlines Co.    192
# Delta Air Lines Inc.      130
# American Airlines Inc.    127
# SkyWest Airlines Inc.     108
# United Air Lines Inc.      71
# JetBlue Airways            38
# Republic Airline           37
# Alaska Airlines Inc.       35
# Envoy Air                  32
# Spirit Air Lines           31
# Name: count, dtype: int64

# %%
top_airline=df['airline'].value_counts()
top_airline = top_airline.nlargest(10)
print(top_airline)

ax =top_airline.plot(kind="bar")
plt.title("Top Airlines")
plt.xlabel("Airlines")
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# airline
# Southwest Airlines Co.    192
# Delta Air Lines Inc.      130
# American Airlines Inc.    127
# SkyWest Airlines Inc.     108
# United Air Lines Inc.      71
# JetBlue Airways            38
# Republic Airline           37
# Alaska Airlines Inc.       35
# Envoy Air                  32
# Spirit Air Lines           31
# Name: count, dtype: int64

# %%
airline_codes = df.sort_values(by='airline_code')
airline_codes
# Out:
#                airline            airline_dot airline_code  dot_code  \
# 506  Endeavor Air Inc.  Endeavor Air Inc.: 9E           9E     20363
# 470  Endeavor Air Inc.  Endeavor Air Inc.: 9E           9E     20363
# 338  Endeavor Air Inc.  Endeavor Air Inc.: 9E           9E     20363
# 480  Endeavor Air Inc.  Endeavor Air Inc.: 9E           9E     20363
# 485  Endeavor Air Inc.  Endeavor Air Inc.: 9E           9E     20363
# ..                 ...                    ...          ...       ...
# 66    Republic Airline   Republic Airline: YX           YX     20452
# 579   Republic Airline   Republic Airline: YX           YX     20452
# 828   Republic Airline   Republic Airline: YX           YX     20452
# 202   Republic Airline   Republic Airline: YX           YX     20452
# 196   Republic Airline   Republic Airline: YX           YX     20452
#
#      fl_number origin       origin_city dest           dest_city  \
# 506       3453    CVG    Cincinnati, OH  LGA        New York, NY
# ...

# %%
avg_DEP_delays_Airlines=df.groupby("airline").mean("flight delay").sort_values
avg_DEP_delays_Airlines
# Out:
# <bound method DataFrame.sort_values of                                     dot_code    fl_number  crs_dep_time  \
# airline
# Alaska Airlines Inc.                 19930.0   687.085714   1493.428571
# Allegiant Air                        20368.0  1128.642857   1407.000000
# American Airlines Inc.               19805.0  1659.842520   1371.488189
# Delta Air Lines Inc.                 19790.0  1469.446154   1303.430769
# Endeavor Air Inc.                    20363.0  4802.133333   1378.900000
# Envoy Air                            20398.0  3866.093750   1265.062500
# ExpressJet Airlines LLC d/b/a aha!   20366.0  4207.777778   1256.444444
# Frontier Airlines Inc.               20436.0  1195.769231   1453.384615
# Hawaiian Airlines Inc.               19690.0   143.700000   1201.000000
# Horizon Air                          19687.0  2307.500000   1526.500000
# JetBlue Airways                      20409.0  1183.342105   1298.631579
# ...

# %%
avg_DEP_delays_Airlines = df.groupby("airline")["dep_delay"].mean().sort_values()
avg_DEP_delays_Airlines
# Out:
# airline
# Horizon Air                           -0.250000
# Envoy Air                              0.419355
# Hawaiian Airlines Inc.                 2.500000
# United Air Lines Inc.                  2.915493
# Delta Air Lines Inc.                   3.062500
# Alaska Airlines Inc.                   3.411765
# SkyWest Airlines Inc.                  4.884615
# Allegiant Air                          6.357143
# PSA Airlines Inc.                      6.500000
# Endeavor Air Inc.                      9.533333
# American Airlines Inc.                 9.626016
# ExpressJet Airlines LLC d/b/a aha!    11.555556
# Mesa Airlines Inc.                    13.000000
# Southwest Airlines Co.                13.854054
# Spirit Air Lines                      14.258065
# Frontier Airlines Inc.                16.384615
# Republic Airline                      34.857143
# JetBlue Airways                       37.081081
# Name: dep_delay, dtype: float64

# %%
plt.bar(avg_DEP_delays_Airlines.index, avg_DEP_delays_Airlines,color='purple')
plt.xlabel('Airline')
plt.ylabel('Mean ARR_delay')
plt.xticks(rotation=90)
plt.show()

# %%
Airline = df['airline'].value_counts()
plt.figure(figsize=(10, 7))
plt.pie(Airline, labels=Airline.index, autopct='%1.1f%%', startangle=10)
plt.title('Airlines by Share of Domestic Flight Volume')
plt.show()

# %%
(
    (
        df
        .query('dep_delay >= 60')
        .origin_city
        .value_counts(normalize=True)
        .head(10)*100
    )
    .round(2)
    .reset_index()
    .rename(columns={'proportion': 'percent'})
)
# Out:
#              origin_city  percent
# 0            Atlanta, GA     8.16
# 1            Seattle, WA     8.16
# 2            Chicago, IL     8.16
# 3             Boston, MA     8.16
# 4  Dallas/Fort Worth, TX     6.12
# 5          Charlotte, NC     4.08
# 6       Indianapolis, IN     4.08
# 7          Baltimore, MD     4.08
# 8          Las Vegas, NV     4.08
# 9           New York, NY     4.08

# %%
top_origin_counts = airline_counts = df['origin'].value_counts().head(30)
top_origin_counts
# Out:
# origin
# ATL    52
# DFW    40
# ORD    39
# DEN    35
# LAX    34
# MSP    30
# BOS    27
# SFO    26
# SEA    26
# MCO    22
# CLT    21
# LAS    21
# PHX    18
# LGA    17
# SLC    17
# IAH    17
# SAN    16
# DTW    16
# FLL    15
# EWR    15
# PHL    14
# JFK    13
# BWI    13
# DCA    13
# BNA    10
# IND    10
# RDU    10
# STL    10
# CMH     9
# TPA     9
# Name: count, dtype: int64

# %%
sns.barplot(x=top_origin_counts.index, y=top_origin_counts.values,color='purple')
plt.xlabel('Origin Airport Name')
plt.ylabel('Count')
plt.title('Top Airports by Outgoing Flight Count')
plt.xticks(rotation=80)
plt.show()

# %%
dest_city_counts = airline_counts = df['dest_city'].value_counts().head(30)
dest_city_counts
# Out:
# dest_city
# Chicago, IL              49
# Atlanta, GA              47
# New York, NY             44
# Dallas/Fort Worth, TX    41
# Los Angeles, CA          30
# Denver, CO               29
# Charlotte, NC            29
# Houston, TX              27
# Seattle, WA              27
# Las Vegas, NV            24
# San Francisco, CA        23
# Newark, NJ               22
# Washington, DC           21
# Orlando, FL              20
# Detroit, MI              19
# Phoenix, AZ              19
# Minneapolis, MN          18
# Salt Lake City, UT       16
# Nashville, TN            16
# Miami, FL                15
# Tampa, FL                13
# Philadelphia, PA         12
# Austin, TX               10
# Fort Lauderdale, FL      10
# Boston, MA               10
# Dallas, TX               10
# San Diego, CA            10
# Raleigh/Durham, NC        9
# Baltimore, MD             9
# Oakland, CA               9
# Name: count, dtype: int64

# %%
dest_city_counts = airline_counts = df['dest_city'].value_counts().head(30)
top_origin_counts = airline_counts = df['origin'].value_counts().head(30)
combined_city_count= dest_city_counts.add(top_origin_counts,fill_value=0)
sorted_combine_count = combined_city_count.sort_values(ascending=False)
top_cities = sorted_combine_count.head(40)
others_count = sorted_combine_count[40:].sum()
top_cities['Others'] = others_count

plt.figure(figsize=(10, 7))
plt.pie(top_cities, labels=top_cities.index, autopct='%1.1f%%', startangle=90)
plt.title('Cities by Share of Flight Count')
plt.show()

# %%
dest_counts = airline_counts = df['dest'].value_counts().head(30)
dest_counts
# Out:
# dest
# ATL    47
# DFW    41
# ORD    37
# LAX    30
# CLT    29
# DEN    29
# SEA    27
# LGA    27
# LAS    24
# SFO    23
# EWR    22
# IAH    20
# MCO    20
# DTW    19
# PHX    19
# MSP    18
# JFK    17
# SLC    16
# BNA    16
# DCA    15
# MIA    15
# TPA    13
# PHL    12
# MDW    12
# AUS    10
# BOS    10
# FLL    10
# SAN    10
# DAL    10
# OAK     9
# Name: count, dtype: int64

# %%
plt.bar(dest_counts,dest_counts)
plt.xlabel('Number of count')
plt.ylabel('dest')
plt.title('Count Plot')
plt.subplots_adjust(left=0.15, right=0.95, top=0.9, bottom=0.1)
plt.show()
